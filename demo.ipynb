# %% [markdown]
# # Assistente Médico com LLM e LangChain
#
# Demonstração do funcionamento do sistema desenvolvido na Fase 3 do Tech Challenge.
#
# Este assistente utiliza:
# - dados do paciente
# - protocolos médicos
# - fluxo de decisão
# - pipeline com LangChain
# - mecanismos de segurança

# %%
from assistant.medical_assistant import MedicalAssistant

# %%
assistant = MedicalAssistant()

# %% [markdown]
# ## Teste 1 — Diagnóstico

# %%
question = "Paciente com glicose alta, como avaliar?"

patient_data = {
    "age": 52,
    "glucose": 180,
    "bmi": 32
}

response = assistant.run(question, patient_data)

print(response["answer"])
print("\nFonte:", response["source"])

# %% [markdown]
# ## Teste 2 — Tratamento

# %%
question = "Como tratar diabetes?"

response = assistant.run(question, patient_data)

print(response["answer"])
print("\nFonte:", response["source"])

# %% [markdown]
# ## Teste 3 — Exames

# %%
question = "Quais exames solicitar?"

response = assistant.run(question, patient_data)

print(response["answer"])
print("\nFonte:", response["source"])
